# %%
import os
import cv2
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Hàm tải và chuẩn bị dữ liệu từ thư mục ảnh
def load_data(data_dir):
    images = []
    labels = []
    for filename in os.listdir(data_dir):
        if filename.endswith(".jpg"):
            label = filename.split("_")[0]
            if label in ["right", "forward", "left"]:
                img = cv2.imread(os.path.join(data_dir, filename))
                img = cv2.resize(img, (224, 224))  # Resize về kích thước 224x224
                images.append(img)
                labels.append(["right", "forward", "left"].index(label))
    return np.array(images), np.array(labels)

# Tải dữ liệu và chia tập huấn luyện/validation
data_dir = "balanced_data"  # Thay bằng đường dẫn thực tế đến thư mục chứa ảnh
images, labels = load_data(data_dir)
train_images, val_images, train_labels, val_labels = train_test_split(images, labels, test_size=0.2, random_state=42)

# Chuẩn hóa dữ liệu (MobileNetV2 yêu cầu giá trị pixel trong [-1, 1])
train_images = tf.keras.applications.mobilenet_v2.preprocess_input(train_images)
val_images = tf.keras.applications.mobilenet_v2.preprocess_input(val_images)

# Định nghĩa mô hình với MobileNetV2
base_model = tf.keras.applications.MobileNetV2(input_shape=(224, 224, 3), include_top=False, weights="imagenet")
base_model.trainable = False  # Không huấn luyện lại MobileNetV2

model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(3, activation="softmax")  # 3 lớp đầu ra: right, forward, left
])

# Compile mô hình
model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])

# Huấn luyện mô hình
history = model.fit(train_images, train_labels, epochs=15, validation_data=(val_images, val_labels))

# Vẽ đồ thị loss
plt.plot(history.history["loss"], label="train_loss")
plt.plot(history.history["val_loss"], label="val_loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training and Validation Loss")
plt.legend()
plt.savefig("loss_plot_clearn.png")  # Lưu đồ thị thành file
plt.close()

# Dự đoán trên tập validation
val_predictions = model.predict(val_images)
val_predictions = np.argmax(val_predictions, axis=1)  # Chuyển từ xác suất sang nhãn

# Tính confusion matrix
cm = confusion_matrix(val_labels, val_predictions)

# Vẽ confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", 
            xticklabels=["right", "forward", "left"], 
            yticklabels=["right", "forward", "left"])
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix on Validation Set")
plt.savefig("confusion_matrix_clean.png")  # Lưu confusion matrix thành file
plt.close()

# Lưu mô hình dưới dạng .tflite
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()
with open("steering_model_balanced.tflite", "wb") as f:
    f.write(tflite_model)
# Out:
# Epoch 1/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 24s 725ms/step - accuracy: 0.5674 - loss: 0.9365 - val_accuracy: 0.8093 - val_loss: 0.5031
# Epoch 2/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 18s 681ms/step - accuracy: 0.8166 - loss: 0.4810 - val_accuracy: 0.9070 - val_loss: 0.3825
# Epoch 3/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 17s 643ms/step - accuracy: 0.9106 - loss: 0.3234 - val_accuracy: 0.9302 - val_loss: 0.3192
# Epoch 4/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 18s 681ms/step - accuracy: 0.9333 - loss: 0.2557 - val_accuracy: 0.9302 - val_loss: 0.2897
# Epoch 5/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 18s 672ms/step - accuracy: 0.9480 - loss: 0.2173 - val_accuracy: 0.9442 - val_loss: 0.2676
# Epoch 6/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 17s 650ms/step - accuracy: 0.9321 - loss: 0.2016 - val_accuracy: 0.9349 - val_loss: 0.2592
# Epoch 7/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 18s 652ms/step - accuracy: 0.9549 - loss: 0.1698 - val_accuracy: 0.9442 - val_loss: 0.2479
# Epoch 8/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 17s 645ms/step - accuracy: 0.9584 - loss: 0.1528 - val_accuracy: 0.9395 - val_loss: 0.2363
# Epoch 9/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 17s 647ms/step - accuracy: 0.9528 - loss: 0.1607 - val_accuracy: 0.9488 - val_loss: 0.2281
# Epoch 10/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 17s
: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2065125750064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2065125749008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2065125751648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2065125739152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2065125749536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2065125740384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2065125805920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2065125808560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2065125804512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2065125806448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2065125814896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2065125813136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2065125815952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2065125804864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2065125814192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2065125810848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2065125919376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2065125921840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2065125917264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2065125920784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2065125926416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2065125925360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2065125928000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2065125923952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2065125925888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2065125930464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2065125966768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2065125965888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2065125932752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2065125967120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2065125930288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2065125973104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2065125975744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2065125971696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2065125973632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2065125981728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2065125978208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2065125977504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2065125978912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2065125977856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2065125980848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2065126070000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2065126072816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2065126068592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2065126071056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2065126078624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2065126077568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2065126080208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2065126067712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2065126078096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2065126068944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2065126183632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2065126186272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2065126182224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2065126184160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2065126194016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2065126192256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2065126189616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2065126182576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2065126193312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2065126189968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2063395853008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2063395855648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2063395851600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2063395853536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2063395860224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2063395859168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2063395861808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2063395857760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2063395859696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2063395864272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2063395933344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2063395934224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2063395930176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2063395933696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2063395940736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2063395939680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2063395942320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2063395938272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2063395940208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2063395945136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2063396012800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2063396012448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2063395944432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2063396014560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2063396021952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2063396020192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2063396023008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2063396015088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2063396021248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2063396025648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2063396025296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2063396025472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2063396026704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2063396110928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2063396019136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2063396117440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2063396120080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2063396116032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2063396117968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2063396126416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2063396121664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2063396122016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2063396122896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2063396125184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2063396122368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2063396181568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2063396184208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2063396180160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2063396182096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2063396188960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2063396187904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2063396190544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2063396186496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2063396188432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2063396364784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2063396362848: TensorSpec(shape=(), dtype=tf.resource, name=None)

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Dự đoán trên tập validation
val_predictions = model.predict(val_images)
val_predictions = np.argmax(val_predictions, axis=1)  # Chuyển từ xác suất sang nhãn

# Tính confusion matrix
cm = confusion_matrix(val_labels, val_predictions)

# Vẽ confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", 
            xticklabels=["right", "forward", "left"], 
            yticklabels=["right", "forward", "left"])
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix on Validation Set")
plt.savefig("confusion_matrix_clean.png")  # Lưu confusion matrix thành file
plt.close()
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 494ms/step

# %%
# # Tải mô hình .tflite
# interpreter = tf.lite.Interpreter(model_path="steering_model_clean.tflite")
# interpreter.allocate_tensors()

# # Lấy thông tin input và output của mô hình
# input_details = interpreter.get_input_details()
# output_details = interpreter.get_output_details()

# # Kiểm tra trên luồng video
# stream_url = "http://192.168.46.130:81/stream"
# cap = cv2.VideoCapture(stream_url)

# while True:
#     ret, frame = cap.read()
#     if not ret:
#         print("Không thể đọc luồng video.")
#         break

#     # Chuẩn bị frame cho dự đoán
#     frame_resized = cv2.resize(frame, (224, 224))
#     frame_processed = tf.keras.applications.mobilenet_v2.preprocess_input(frame_resized)
#     input_data = np.expand_dims(frame_processed, axis=0).astype(np.float32)

#     # Đặt dữ liệu đầu vào và chạy dự đoán
#     interpreter.set_tensor(input_details[0]["index"], input_data)
#     interpreter.invoke()

#     # Lấy kết quả dự đoán
#     output_data = interpreter.get_tensor(output_details[0]["index"])
#     prediction = np.argmax(output_data[0])
#     result = ["right", "forward", "left"][prediction]
#     print(f"Dự đoán: {result}")

#     # Hiển thị frame (tùy chọn)
#     cv2.imshow("Video Stream", frame)
#     if cv2.waitKey(1) & 0xFF == ord("q"):  # Nhấn 'q' để thoát
#         break

# # Giải phóng tài nguyên
# cap.release()
# cv2.destroyAllWindows()
