# %%
import os
import cv2
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# Hàm tải và chuẩn bị dữ liệu từ thư mục ảnh
def load_data(data_dir):
    images = []
    labels = []
    for filename in os.listdir(data_dir):
        if filename.endswith(".jpg"):
            label = filename.split("_")[0]
            if label in ["right", "forward", "left"]:
                img = cv2.imread(os.path.join(data_dir, filename))
                img = cv2.resize(img, (224, 224))  # Resize về kích thước 224x224
                images.append(img)
                labels.append(["right", "forward", "left"].index(label))
    return np.array(images), np.array(labels)

# Tải dữ liệu và chia tập huấn luyện/validation
data_dir = "dataset"  # Thay bằng đường dẫn thực tế đến thư mục chứa ảnh
images, labels = load_data(data_dir)
train_images, val_images, train_labels, val_labels = train_test_split(images, labels, test_size=0.2, random_state=42)

# Chuẩn hóa dữ liệu (MobileNetV2 yêu cầu giá trị pixel trong [-1, 1])
train_images = tf.keras.applications.mobilenet_v2.preprocess_input(train_images)
val_images = tf.keras.applications.mobilenet_v2.preprocess_input(val_images)

# Định nghĩa mô hình với MobileNetV2
base_model = tf.keras.applications.MobileNetV2(input_shape=(224, 224, 3), include_top=False, weights="imagenet")
base_model.trainable = False  # Không huấn luyện lại MobileNetV2

model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(3, activation="softmax")  # 3 lớp đầu ra: right, forward, left
])

# Compile mô hình
model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])

# Huấn luyện mô hình
history = model.fit(train_images, train_labels, epochs=50, validation_data=(val_images, val_labels))

# Vẽ đồ thị loss
plt.plot(history.history["loss"], label="train_loss")
plt.plot(history.history["val_loss"], label="val_loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training and Validation Loss")
plt.legend()
plt.savefig("loss_plot.png")  # Lưu đồ thị thành file
plt.close()

# Lưu mô hình dưới dạng .tflite
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()
with open("steering_model.tflite", "wb") as f:
    f.write(tflite_model)
# Out:
# Epoch 1/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 21s 749ms/step - accuracy: 0.4484 - loss: 1.4187 - val_accuracy: 0.5176 - val_loss: 1.0073
# Epoch 2/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 14s 649ms/step - accuracy: 0.5791 - loss: 0.9555 - val_accuracy: 0.5471 - val_loss: 0.9213
# Epoch 3/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 14s 656ms/step - accuracy: 0.5873 - loss: 0.8956 - val_accuracy: 0.5529 - val_loss: 0.9407
# Epoch 4/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 15s 682ms/step - accuracy: 0.5863 - loss: 0.8864 - val_accuracy: 0.5471 - val_loss: 0.8905
# Epoch 5/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 15s 671ms/step - accuracy: 0.5590 - loss: 0.8883 - val_accuracy: 0.5529 - val_loss: 0.8885
# Epoch 6/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 15s 683ms/step - accuracy: 0.6084 - loss: 0.8382 - val_accuracy: 0.5471 - val_loss: 0.9009
# Epoch 7/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 14s 635ms/step - accuracy: 0.6206 - loss: 0.8252 - val_accuracy: 0.5294 - val_loss: 0.9135
# Epoch 8/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 14s 658ms/step - accuracy: 0.6254 - loss: 0.8156 - val_accuracy: 0.5824 - val_loss: 0.8737
# Epoch 9/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 14s 641ms/step - accuracy: 0.6551 - loss: 0.7665 - val_accuracy: 0.6000 - val_loss: 0.8597
# Epoch 10/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 14s 624ms/step - accuracy: 0.6439 - loss: 0.7740 - val_accuracy: 0.5765 - val_loss: 0.8618
# Epoch 11/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 14s 658ms/step - accuracy: 0.6757 - loss: 0.7542 - val_accuracy: 0.5941 - val_loss: 0.8609
# Epoch 12/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 15s 672ms/step - accuracy: 0.6784 - loss: 0.7093 - val_accuracy: 0.5824 - val_loss: 0.9055
# Epoch 13/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 14s 642ms/step - accuracy: 0.6597 - loss: 0.7495 - val_accuracy: 0.5824 - val_loss: 0.9112
# Epoch 14/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 14s 618ms/step - accuracy: 0.6906 - loss: 0.6863 - val_accuracy: 0.5824 - val_loss: 0.8783
# Epoch 15/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 14s 621ms/step - accuracy: 0.6737 - loss: 0.6905 - val_accuracy: 0.5941 - val_loss: 0.8904
# Epoch 16/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 14s 649ms/step - accuracy: 0.6832 - loss: 0.7210 - val_accuracy: 0.6059 - val_loss: 0.8748
# Epoch 17/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 14s 642ms/step - accuracy: 0.7120 - loss: 0.6779 - val_accuracy: 0.5765 - val_loss: 0.9107
# Epoch 18/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 14s 657ms/step - accuracy: 0.7174 - loss: 0.6515 - val_accuracy: 0.5824 - val_loss: 0.9041
# Epoch 19/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 16s 713ms/step - accuracy: 0.7140 - loss: 0.6980 - val_accuracy: 0.5706 - val_loss: 0.8892
# Epoch 20/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 17s 761ms/step - accuracy: 0.7107 - loss: 0.6653 - val_accuracy: 0.5647 - val_loss: 0.9272
# Epoch 21/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 15s 690ms/step - accuracy: 0.6836 - loss: 0.7168 - val_accuracy: 0.5706 - val_loss: 0.8954
# Epoch 22/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 14s 651ms/step - accuracy: 0.7393 - loss: 0.6269 - val_accuracy: 0.5647 - val_loss: 0.8828
# Epoch 23/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 15s 669ms/step - accuracy: 0.7414 - loss: 0.6230 - val_accuracy: 0.5882 - val_loss: 0.9017
# Epoch 24/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 15s 694ms/step - accuracy: 0.7893 - loss: 0.5839 - val_accuracy: 0.5882 - val_loss: 0.8982
# Epoch 25/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 14s 645ms/step - accuracy: 0.7836 - loss: 0.5873 - val_accuracy: 0.5882 - val_loss: 0.9043
# Epoch 26/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 15s 669ms/step - accuracy: 0.7444 - loss: 0.6209 - val_accuracy: 0.6000 - val_loss: 0.9049
# Epoch 27/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 14s 649ms/step - accuracy: 0.7598 - loss: 0.5896 - val_accuracy: 0.5706 - val_loss: 0.8880
# Epoch 28/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 15s 674ms/step - accuracy: 0.7622 - loss: 0.6144 - val_accuracy: 0.5882 - val_loss: 0.8916
# Epoch 29/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 14s 638ms/step - accuracy: 0.7899 - loss: 0.5591 - val_accuracy: 0.5706 - val_loss: 0.9350
# Epoch 30/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 14s 647ms/step - accuracy: 0.7317 - loss: 0.6318 - val_accuracy: 0.5529 - val_loss: 0.9286
# Epoch 31/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 14s 645ms/step - accuracy: 0.7483 - loss: 0.5794 - val_accuracy: 0.5706 - val_loss: 0.9901
# Epoch 32/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 15s 672ms/step - accuracy: 0.7261 - loss: 0.5808 - val_accuracy: 0.5529 - val_loss: 0.9159
# Epoch 33/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 15s 693ms/step - accuracy: 0.7976 - loss: 0.5327 - val_accuracy: 0.5765 - val_loss: 0.9269
# Epoch 34/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 14s
: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233181856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233187840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233256912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233255152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233187136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233257264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233187664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233263248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233265888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233261840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233263776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233270464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233266944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233264480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233267648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233270640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233269584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233358736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233361552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233357328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233359792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233367360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233366304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233368944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233356448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233366832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233357680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233472368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233475008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233470960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233472896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233481344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233479584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233482400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233471312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233480640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233477296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233553056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233555520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233550944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233554464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233478528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233560448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233563088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233559040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233560976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233559392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233634976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233637088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233632864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233636384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233643424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233642368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233645008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233632512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233642896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233646416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233746848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233746496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233645712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233748608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233756000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233754240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233757056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233749136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233755296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233759696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233759344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233759520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233760752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233829648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233753184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233835104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233837744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233833696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233835632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233844080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233839328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233839680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233841088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233843200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233840032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233915616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233918256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233914208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233916144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233842672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233923184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233925824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233921776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233923712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984233922128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984234012512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984234015328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984234011104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984234013568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984234021136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984234020080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984234022720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984234010224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984234020608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984234011456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984234109936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984234112400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984234107824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984234111344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984234118736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984234116976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984234119792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984234108000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984234118032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984234122432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984234206480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984234206128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984234208768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984234208240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984234115920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984234212816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984234215456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984234211408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984234213344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984234217920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984234217040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984234217392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984234218976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984234221264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984234217744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984234309712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984234312352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984234308304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984234310240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984234220032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984234317280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984234314112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984234315872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984234317808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984234316224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984234422992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984234425808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984234421584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984234424048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984234431616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984234430560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984234433200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984234420704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984234431088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984234421936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984234520240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984234522880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984234518832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984234520768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984234530624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984234528864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984234531680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984234519184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984234529920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984234526576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984234618544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984234621184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984234617136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984234619072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984234527808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984234624704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984234627344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984234623296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984234625232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984234629808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984234715264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984234713504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984234629104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984234715616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984234629632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984234721600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984234724240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984234720192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984234722128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984234727056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984241201920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984241202976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984234728112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984241201216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984234726352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984241208256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984241211072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984241206848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984241209312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984241216880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984241213360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984241212656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984241214064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984241213008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984241207200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984241321888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984241324528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984241320480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984241322416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984241330864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984241329104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984241331920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984241320832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984241330160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984241326816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984241435168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984241437808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984241433760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984241435696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984241328048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984241441504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984241444144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984241440096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984241442032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984241831200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984241829264: TensorSpec(shape=(), dtype=tf.resource, name=None)

# %%
# Tải mô hình .tflite
interpreter = tf.lite.Interpreter(model_path="steering_model.tflite")
interpreter.allocate_tensors()

# Lấy thông tin input và output của mô hình
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

# Kiểm tra trên luồng video
stream_url = "http://192.168.46.130:81/stream"
cap = cv2.VideoCapture(stream_url)

while True:
    ret, frame = cap.read()
    if not ret:
        print("Không thể đọc luồng video.")
        break

    # Chuẩn bị frame cho dự đoán
    frame_resized = cv2.resize(frame, (224, 224))
    frame_processed = tf.keras.applications.mobilenet_v2.preprocess_input(frame_resized)
    input_data = np.expand_dims(frame_processed, axis=0).astype(np.float32)

    # Đặt dữ liệu đầu vào và chạy dự đoán
    interpreter.set_tensor(input_details[0]["index"], input_data)
    interpreter.invoke()

    # Lấy kết quả dự đoán
    output_data = interpreter.get_tensor(output_details[0]["index"])
    prediction = np.argmax(output_data[0])
    result = ["right", "forward", "left"][prediction]
    print(f"Dự đoán: {result}")

    # Hiển thị frame (tùy chọn)
    cv2.imshow("Video Stream", frame)
    if cv2.waitKey(1) & 0xFF == ord("q"):  # Nhấn 'q' để thoát
        break

# Giải phóng tài nguyên
cap.release()
cv2.destroyAllWindows()
# Out:
# Không thể đọc luồng video.
