# %%
import os
import cv2
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Hàm tải và chuẩn bị dữ liệu từ thư mục ảnh
def load_data(data_dir):
    images = []
    labels = []
    for filename in os.listdir(data_dir):
        if filename.endswith(".jpg"):
            label = filename.split("_")[0]
            if label in ["right", "forward", "left"]:
                img = cv2.imread(os.path.join(data_dir, filename))
                img = cv2.resize(img, (224, 224))  # Resize về kích thước 224x224
                images.append(img)
                labels.append(["right", "forward", "left"].index(label))
    return np.array(images), np.array(labels)

# Tải dữ liệu và chia tập huấn luyện/validation
data_dir = "dataset_clean"  # Thay bằng đường dẫn thực tế đến thư mục chứa ảnh
images, labels = load_data(data_dir)
train_images, val_images, train_labels, val_labels = train_test_split(images, labels, test_size=0.2, random_state=42)

# Chuẩn hóa dữ liệu (MobileNetV2 yêu cầu giá trị pixel trong [-1, 1])
train_images = tf.keras.applications.mobilenet_v2.preprocess_input(train_images)
val_images = tf.keras.applications.mobilenet_v2.preprocess_input(val_images)

# Định nghĩa mô hình với MobileNetV2
base_model = tf.keras.applications.MobileNetV2(input_shape=(224, 224, 3), include_top=False, weights="imagenet")
base_model.trainable = False  # Không huấn luyện lại MobileNetV2

model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(3, activation="softmax")  # 3 lớp đầu ra: right, forward, left
])

# Compile mô hình
model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])

# Huấn luyện mô hình
history = model.fit(train_images, train_labels, epochs=50, validation_data=(val_images, val_labels))

# Vẽ đồ thị loss
plt.plot(history.history["loss"], label="train_loss")
plt.plot(history.history["val_loss"], label="val_loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training and Validation Loss")
plt.legend()
plt.savefig("loss_plot_clearn.png")  # Lưu đồ thị thành file
plt.close()

# Dự đoán trên tập validation
val_predictions = model.predict(val_images)
val_predictions = np.argmax(val_predictions, axis=1)  # Chuyển từ xác suất sang nhãn

# Tính confusion matrix
cm = confusion_matrix(val_labels, val_predictions)

# Vẽ confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", 
            xticklabels=["right", "forward", "left"], 
            yticklabels=["right", "forward", "left"])
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix on Validation Set")
plt.savefig("confusion_matrix_clean.png")  # Lưu confusion matrix thành file
plt.close()

# Lưu mô hình dưới dạng .tflite
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()
with open("steering_model_clean.tflite", "wb") as f:
    f.write(tflite_model)
# Out:
# Epoch 1/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 19s 734ms/step - accuracy: 0.4762 - loss: 1.1476 - val_accuracy: 0.4545 - val_loss: 1.0496
# Epoch 2/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 14s 676ms/step - accuracy: 0.5717 - loss: 0.9597 - val_accuracy: 0.5212 - val_loss: 0.9427
# Epoch 3/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 14s 666ms/step - accuracy: 0.5996 - loss: 0.8834 - val_accuracy: 0.5333 - val_loss: 0.9019
# Epoch 4/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 14s 659ms/step - accuracy: 0.6379 - loss: 0.8356 - val_accuracy: 0.5515 - val_loss: 0.9079
# Epoch 5/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 14s 655ms/step - accuracy: 0.6038 - loss: 0.8443 - val_accuracy: 0.5333 - val_loss: 0.9053
# Epoch 6/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 14s 649ms/step - accuracy: 0.6473 - loss: 0.7932 - val_accuracy: 0.5515 - val_loss: 0.8855
# Epoch 7/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 14s 649ms/step - accuracy: 0.6841 - loss: 0.7586 - val_accuracy: 0.5636 - val_loss: 0.8845
# Epoch 8/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 14s 664ms/step - accuracy: 0.6668 - loss: 0.7634 - val_accuracy: 0.5455 - val_loss: 0.8700
# Epoch 9/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 14s 652ms/step - accuracy: 0.7140 - loss: 0.7240 - val_accuracy: 0.5333 - val_loss: 0.8860
# Epoch 10/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 14s
: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984358508352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984358499200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984358351744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984358354384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984358350336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984358352272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984358360720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984358358960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984358361776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984358350688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984358360016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984358356672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984358628864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984358631504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984358627456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984358629392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984358637488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984358636432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984358639072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984358635024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984358636960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984358635376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984357858640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984357859696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984357855472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984357858992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984357866032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984357864976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984357867616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984357863568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984357865504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984357870432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984358593456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984358593104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984358593280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984358595216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984358602608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984358600848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984358603664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984358594688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984358601904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984358606304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984358314576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984358606128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984358607360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984358314048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984358599792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984358319856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984358322496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984358318448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984358320384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984358328832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984358327072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984358329888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984358318800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984358328128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984358324784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984358449520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984358452160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984358448112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984358450048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984358458144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984358457088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984358459728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984358455680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984358457616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984358456032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984358694048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984358696160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984358691936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984358695456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984358702496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984358701440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984358704080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984358691584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984358701968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984358706896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2985092777760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2985092779872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2985092776000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2985092779520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2985092788320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2985092786560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2985092789376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2985092776176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2985092787616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2985092792016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2985093089056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2985093091168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2985093087296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2985093090816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2985093096448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2985093095392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2985093098032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2985093093984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2985093095920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2985093100496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2985093099616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2985093099264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2985093101552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2985093039024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2985093100320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2985093044832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2985093047472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2985093043424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2985093045360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2985093053456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2985093049936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2985093049232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2985093050640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2985093053632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2985093052576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2985093338336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2985093341152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2985093336928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2985093339392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2985093346960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2985093345904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2985093348544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2985093336048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2985093346432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2985093337280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2985093140672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2985093143312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2985093139264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2985093141200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2985093149648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2985093147888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2985093150704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2985093139616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2985093148944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2985093145600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2985093385200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2985093387664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2985093383088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2985093386608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2985093392416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2985093391360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2985093394000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2985093389952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2985093391888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2985092388592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2985092386656: TensorSpec(shape=(), dtype=tf.resource, name=None)

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Dự đoán trên tập validation
val_predictions = model.predict(val_images)
val_predictions = np.argmax(val_predictions, axis=1)  # Chuyển từ xác suất sang nhãn

# Tính confusion matrix
cm = confusion_matrix(val_labels, val_predictions)

# Vẽ confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", 
            xticklabels=["right", "forward", "left"], 
            yticklabels=["right", "forward", "left"])
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix on Validation Set")
plt.savefig("confusion_matrix_clean.png")  # Lưu confusion matrix thành file
plt.close()
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 494ms/step

# %%
# # Tải mô hình .tflite
# interpreter = tf.lite.Interpreter(model_path="steering_model_clean.tflite")
# interpreter.allocate_tensors()

# # Lấy thông tin input và output của mô hình
# input_details = interpreter.get_input_details()
# output_details = interpreter.get_output_details()

# # Kiểm tra trên luồng video
# stream_url = "http://192.168.46.130:81/stream"
# cap = cv2.VideoCapture(stream_url)

# while True:
#     ret, frame = cap.read()
#     if not ret:
#         print("Không thể đọc luồng video.")
#         break

#     # Chuẩn bị frame cho dự đoán
#     frame_resized = cv2.resize(frame, (224, 224))
#     frame_processed = tf.keras.applications.mobilenet_v2.preprocess_input(frame_resized)
#     input_data = np.expand_dims(frame_processed, axis=0).astype(np.float32)

#     # Đặt dữ liệu đầu vào và chạy dự đoán
#     interpreter.set_tensor(input_details[0]["index"], input_data)
#     interpreter.invoke()

#     # Lấy kết quả dự đoán
#     output_data = interpreter.get_tensor(output_details[0]["index"])
#     prediction = np.argmax(output_data[0])
#     result = ["right", "forward", "left"][prediction]
#     print(f"Dự đoán: {result}")

#     # Hiển thị frame (tùy chọn)
#     cv2.imshow("Video Stream", frame)
#     if cv2.waitKey(1) & 0xFF == ord("q"):  # Nhấn 'q' để thoát
#         break

# # Giải phóng tài nguyên
# cap.release()
# cv2.destroyAllWindows()
