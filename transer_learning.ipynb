# %%
import os
import cv2
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Hàm tải và chuẩn bị dữ liệu từ thư mục ảnh
def load_data(data_dir):
    images = []
    labels = []
    for filename in os.listdir(data_dir):
        if filename.endswith(".jpg"):
            label = filename.split("_")[0]
            if label in ["right", "forward", "left"]:
                img = cv2.imread(os.path.join(data_dir, filename))
                img = cv2.resize(img, (224, 224))  # Resize về kích thước 224x224
                images.append(img)
                labels.append(["right", "forward", "left"].index(label))
    return np.array(images), np.array(labels)

# Tải dữ liệu và chia tập huấn luyện/validation
data_dir = "dataset_clean"  # Thay bằng đường dẫn thực tế đến thư mục chứa ảnh
images, labels = load_data(data_dir)
train_images, val_images, train_labels, val_labels = train_test_split(images, labels, test_size=0.2, random_state=42)

# Chuẩn hóa dữ liệu (MobileNetV2 yêu cầu giá trị pixel trong [-1, 1])
train_images = tf.keras.applications.mobilenet_v2.preprocess_input(train_images)
val_images = tf.keras.applications.mobilenet_v2.preprocess_input(val_images)

# Định nghĩa mô hình với MobileNetV2
base_model = tf.keras.applications.MobileNetV2(input_shape=(224, 224, 3), include_top=False, weights="imagenet")
base_model.trainable = False  # Không huấn luyện lại MobileNetV2

model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(3, activation="softmax")  # 3 lớp đầu ra: right, forward, left
])

# Compile mô hình
model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])

# Huấn luyện mô hình
history = model.fit(train_images, train_labels, epochs=50, validation_data=(val_images, val_labels))

# Vẽ đồ thị loss
plt.plot(history.history["loss"], label="train_loss")
plt.plot(history.history["val_loss"], label="val_loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training and Validation Loss")
plt.legend()
plt.savefig("loss_plot_clearn.png")  # Lưu đồ thị thành file
plt.close()

# Dự đoán trên tập validation
val_predictions = model.predict(val_images)
val_predictions = np.argmax(val_predictions, axis=1)  # Chuyển từ xác suất sang nhãn

# Tính confusion matrix
cm = confusion_matrix(val_labels, val_predictions)

# Vẽ confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", 
            xticklabels=["right", "forward", "left"], 
            yticklabels=["right", "forward", "left"])
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix on Validation Set")
plt.savefig("confusion_matrix_clean.png")  # Lưu confusion matrix thành file
plt.close()

# Lưu mô hình dưới dạng .tflite
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()
with open("steering_model_clean.tflite", "wb") as f:
    f.write(tflite_model)
# Out:
# Epoch 1/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 21s 768ms/step - accuracy: 0.4667 - loss: 1.0702 - val_accuracy: 0.6358 - val_loss: 0.7342
# Epoch 2/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 14s 689ms/step - accuracy: 0.6913 - loss: 0.6986 - val_accuracy: 0.7346 - val_loss: 0.6414
# Epoch 3/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 14s 676ms/step - accuracy: 0.7746 - loss: 0.5892 - val_accuracy: 0.8025 - val_loss: 0.5722
# Epoch 4/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 14s 665ms/step - accuracy: 0.8043 - loss: 0.5611 - val_accuracy: 0.7160 - val_loss: 0.5963
# Epoch 5/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 14s 673ms/step - accuracy: 0.8153 - loss: 0.4972 - val_accuracy: 0.7901 - val_loss: 0.5227
# Epoch 6/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 14s 665ms/step - accuracy: 0.8605 - loss: 0.4288 - val_accuracy: 0.8210 - val_loss: 0.4829
# Epoch 7/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 14s 669ms/step - accuracy: 0.8697 - loss: 0.4010 - val_accuracy: 0.8086 - val_loss: 0.4811
# Epoch 8/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 14s 669ms/step - accuracy: 0.8802 - loss: 0.3980 - val_accuracy: 0.8272 - val_loss: 0.4556
# Epoch 9/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 14s
: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984167050576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984167051632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984167047408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984167050928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984167057968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984167056912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984167059552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984167055504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984167057440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984167062368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984167867312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984167866960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984167867136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984167869072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984167876464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984167874704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984167877520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984167868544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984167875760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984167880160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984167211600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984167879984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984167881216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984167211072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984167873648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984167218288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984167220928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984167216880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984167218816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984167223392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984167222512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984167222864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984167224448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984167222688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984167223216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984167708400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984167711040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984167706992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984167708928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984167717024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984167715968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984167718608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984167714560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984167716496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984167714912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984167674224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984167677040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984167672816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984167675280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984167682848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984167681792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984167684432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984167671936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984167682320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984167685840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984166950688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984166952800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984166948928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984166952448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984166959840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984166958080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984166960896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984166949104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984166959136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984166963536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984167391648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984167391296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984166962832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984167393408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984167400448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984167399392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984167402032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984167397984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984167399920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984167404496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984167403616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984167403264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984167405552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984167424944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984167404320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984167430752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984167433392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984167429344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984167431280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984167439376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984167435856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984167435152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984167436560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984167439552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984167438496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984158960224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984158963040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984158958816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984158961280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984158968848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984158965328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984158964624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984158966032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984158969024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984158959168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984158843072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984158845712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984158841664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984158843600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984158852048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984158850288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984158853104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984158842016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984158851344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984158848000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984159054832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984159057296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984159052720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984159056240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984159063280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984159062224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984159064864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984159060816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984159062752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984159067328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984159300240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984159297952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984159301296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984159300592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984159307632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984159306576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984159309216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984159305168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984159307104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984159312032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984159330544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984159330720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984159313616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984159332304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984159339696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984159337936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984159340752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984159332656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984159338992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984159343392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984159343040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984159342336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984159344448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984159232944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984159336880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984159237344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984159239984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984159235936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984159237872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984159244736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2984163724800: TensorSpec(shape=(), dtype=tf.resource, name=None)

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Dự đoán trên tập validation
val_predictions = model.predict(val_images)
val_predictions = np.argmax(val_predictions, axis=1)  # Chuyển từ xác suất sang nhãn

# Tính confusion matrix
cm = confusion_matrix(val_labels, val_predictions)

# Vẽ confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", 
            xticklabels=["right", "forward", "left"], 
            yticklabels=["right", "forward", "left"])
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix on Validation Set")
plt.savefig("confusion_matrix_clean.png")  # Lưu confusion matrix thành file
plt.close()
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 450ms/step

# %%
# # Tải mô hình .tflite
# interpreter = tf.lite.Interpreter(model_path="steering_model_clean.tflite")
# interpreter.allocate_tensors()

# # Lấy thông tin input và output của mô hình
# input_details = interpreter.get_input_details()
# output_details = interpreter.get_output_details()

# # Kiểm tra trên luồng video
# stream_url = "http://192.168.46.130:81/stream"
# cap = cv2.VideoCapture(stream_url)

# while True:
#     ret, frame = cap.read()
#     if not ret:
#         print("Không thể đọc luồng video.")
#         break

#     # Chuẩn bị frame cho dự đoán
#     frame_resized = cv2.resize(frame, (224, 224))
#     frame_processed = tf.keras.applications.mobilenet_v2.preprocess_input(frame_resized)
#     input_data = np.expand_dims(frame_processed, axis=0).astype(np.float32)

#     # Đặt dữ liệu đầu vào và chạy dự đoán
#     interpreter.set_tensor(input_details[0]["index"], input_data)
#     interpreter.invoke()

#     # Lấy kết quả dự đoán
#     output_data = interpreter.get_tensor(output_details[0]["index"])
#     prediction = np.argmax(output_data[0])
#     result = ["right", "forward", "left"][prediction]
#     print(f"Dự đoán: {result}")

#     # Hiển thị frame (tùy chọn)
#     cv2.imshow("Video Stream", frame)
#     if cv2.waitKey(1) & 0xFF == ord("q"):  # Nhấn 'q' để thoát
#         break

# # Giải phóng tài nguyên
# cap.release()
# cv2.destroyAllWindows()
