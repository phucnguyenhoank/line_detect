# %%
import os
import cv2
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# Hàm tải và chuẩn bị dữ liệu từ thư mục ảnh
def load_data(data_dir):
    images = []
    labels = []
    for filename in os.listdir(data_dir):
        if filename.endswith(".jpg"):
            label = filename.split("_")[0]
            if label in ["right", "forward", "left"]:
                img = cv2.imread(os.path.join(data_dir, filename))
                img = cv2.resize(img, (224, 224))  # Resize về kích thước 224x224
                images.append(img)
                labels.append(["right", "forward", "left"].index(label))
    return np.array(images), np.array(labels)

# Tải dữ liệu và chia tập huấn luyện/validation
data_dir = "dataset"  # Thay bằng đường dẫn thực tế đến thư mục chứa ảnh
images, labels = load_data(data_dir)
train_images, val_images, train_labels, val_labels = train_test_split(images, labels, test_size=0.2, random_state=42)

# Chuẩn hóa dữ liệu (MobileNetV2 yêu cầu giá trị pixel trong [-1, 1])
train_images = tf.keras.applications.mobilenet_v2.preprocess_input(train_images)
val_images = tf.keras.applications.mobilenet_v2.preprocess_input(val_images)

# Định nghĩa mô hình với MobileNetV2
base_model = tf.keras.applications.MobileNetV2(input_shape=(224, 224, 3), include_top=False, weights="imagenet")
base_model.trainable = False  # Không huấn luyện lại MobileNetV2

model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(3, activation="softmax")  # 3 lớp đầu ra: right, forward, left
])

# Compile mô hình
model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])

# Huấn luyện mô hình
history = model.fit(train_images, train_labels, epochs=50, validation_data=(val_images, val_labels))

# Vẽ đồ thị loss
plt.plot(history.history["loss"], label="train_loss")
plt.plot(history.history["val_loss"], label="val_loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training and Validation Loss")
plt.legend()
plt.savefig("loss_plot.png")  # Lưu đồ thị thành file
plt.close()

# Lưu mô hình dưới dạng .tflite
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()
with open("steering_model.tflite", "wb") as f:
    f.write(tflite_model)
# Out:
# Epoch 1/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 14s 675ms/step - accuracy: 0.5295 - loss: 1.0513 - val_accuracy: 0.5905 - val_loss: 0.9217
# Epoch 2/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 8s 607ms/step - accuracy: 0.5834 - loss: 0.9446 - val_accuracy: 0.5524 - val_loss: 0.9372
# Epoch 3/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 8s 599ms/step - accuracy: 0.5864 - loss: 0.9126 - val_accuracy: 0.5714 - val_loss: 0.9288
# Epoch 4/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 8s 610ms/step - accuracy: 0.5996 - loss: 0.8902 - val_accuracy: 0.5905 - val_loss: 0.8776
# Epoch 5/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 8s 589ms/step - accuracy: 0.6532 - loss: 0.8568 - val_accuracy: 0.6190 - val_loss: 0.9124
# Epoch 6/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 8s 582ms/step - accuracy: 0.6400 - loss: 0.8759 - val_accuracy: 0.5714 - val_loss: 0.8704
# Epoch 7/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 8s 580ms/step - accuracy: 0.6925 - loss: 0.7992 - val_accuracy: 0.5810 - val_loss: 0.9157
# Epoch 8/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 8s 587ms/step - accuracy: 0.6427 - loss: 0.7964 - val_accuracy: 0.5905 - val_loss: 0.9288
# Epoch 9/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 8s 580ms/step - accuracy: 0.6187 - loss: 0.8370 - val_accuracy: 0.6000 - val_loss: 0.8855
# Epoch 10/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 8s 578ms/step - accuracy: 0.6605 - loss: 0.7722 - val_accuracy: 0.6095 - val_loss: 0.8847
# Epoch 11/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 8s 602ms/step - accuracy: 0.6645 - loss: 0.7822 - val_accuracy: 0.6000 - val_loss: 0.9034
# Epoch 12/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 8s
: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210341861008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210341947520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210341861536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210341953504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210341956144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210341952096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210341954032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210341960720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210341957200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210341954736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210341957904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210341960896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210341959840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342048992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342051808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342047584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342050048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342057616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342056560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342059200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342046704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342057088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342047936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342146240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342148880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342144832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342146768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342155216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342153456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342156272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342145184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342154512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342151168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342226928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342229392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342224816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342228336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342152400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342234320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342236960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342232912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342234848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342233264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342326288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342327344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342323120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342326640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342333680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342332624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342335264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342322768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342333152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342336672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342420720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342420896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342338256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342422480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342429872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342428112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342430928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342422832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342429168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342433568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342433216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342432512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342434624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342503344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342427056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342508976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342511616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342507568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342509504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342517952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342516192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342513552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342507920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342517248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342513904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342605872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342608512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342604464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342606400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342515136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342613440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342616080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342612032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342613968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342612384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342702768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342705584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342701360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342703824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342711392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342710336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342712976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342700480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342710864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342701712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342783808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342786272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342781696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342785216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342792608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342790848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342793664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342781872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342791904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342796304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342880352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342880000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342882464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342882112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342789792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342886688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342889328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342885280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342887216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342891792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342890912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342891264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342892848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342895136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342891616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342999968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210343002608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342998560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210343000496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210342893904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210343007536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210343004368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210343006128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210343008064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210343006480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210343096864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210343099680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210343095456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210343097920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210343105488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210343104432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210343107072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210343094576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210343104960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210343095808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210343194112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210343196752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210343192704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210343194640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210343204496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210343202736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210343205552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210343193056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210343203792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210343200448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210343292416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210343295056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210343291008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210343292944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210343201680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210343298576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210343301216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210343297168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210343299104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210343303680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210343405520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210343403760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210343302976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210343405872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210343303504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210343411856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210343414496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210343410448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210343412384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210343417312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210343453264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210343417136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210343418368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210343452736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210343418896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210343459600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210343462416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210343458192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210343460656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210343468224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210343464704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210343464000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210343465408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210343468400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210343458544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210349995760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210349998400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210349994352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210349996288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210350004736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210350002976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210350005792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210349994704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210350004032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210350000688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210350109040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210350111680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210350107632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210350109568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210350001920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210350115376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210350118016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210350113968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210350115904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210350488688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2210350486752: TensorSpec(shape=(), dtype=tf.resource, name=None)

# %%
# Tải mô hình .tflite
interpreter = tf.lite.Interpreter(model_path="steering_model.tflite")
interpreter.allocate_tensors()

# Lấy thông tin input và output của mô hình
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

# Kiểm tra trên luồng video
stream_url = "http://192.168.46.130:81/stream"
cap = cv2.VideoCapture(stream_url)

while True:
    ret, frame = cap.read()
    if not ret:
        print("Không thể đọc luồng video.")
        break

    # Chuẩn bị frame cho dự đoán
    frame_resized = cv2.resize(frame, (224, 224))
    frame_processed = tf.keras.applications.mobilenet_v2.preprocess_input(frame_resized)
    input_data = np.expand_dims(frame_processed, axis=0).astype(np.float32)

    # Đặt dữ liệu đầu vào và chạy dự đoán
    interpreter.set_tensor(input_details[0]["index"], input_data)
    interpreter.invoke()

    # Lấy kết quả dự đoán
    output_data = interpreter.get_tensor(output_details[0]["index"])
    prediction = np.argmax(output_data[0])
    result = ["right", "forward", "left"][prediction]
    print(f"Dự đoán: {result}")

    # Hiển thị frame (tùy chọn)
    cv2.imshow("Video Stream", frame)
    if cv2.waitKey(1) & 0xFF == ord("q"):  # Nhấn 'q' để thoát
        break

# Giải phóng tài nguyên
cap.release()
cv2.destroyAllWindows()
